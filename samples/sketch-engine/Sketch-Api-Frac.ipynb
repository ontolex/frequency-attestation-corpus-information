# %% [markdown]
# Sketchengine API for OntoLex FrAC Module
# ===
# OntoLex Module for Frequency, Attestation and Corpus Information (FrAC)
#
# Ranka Stanković, University of Belgrade; 25.1.2021

# %% [markdown]
# Detailed documentation for Sketchengine API available at: https://www.sketchengine.eu/documentation/api-documentation/
# See FUP (Fair Use Policy) at https://www.sketchengine.eu/fair-use-policy/
# For fewer than 100 requests, you may not need to wait at all. For 100–900 requests, 4 seconds recommended.
# For more than 900 requests, it is best to wait at least 45 seconds.
#
# For methods and attributes in Sketch Engine API see https://www.sketchengine.eu/documentation/methods-documentation/

# %%
import requests
# insert user name for https://auth.sketchengine.eu 
USERNAME =  ' '  
# when logged in, click the three-dot icon at the top-right corner of the screen and select My account
# click the Generate new API key button (the API key is a long string of letters and numbers)
API_KEY = ' '
base_url = 'https://api.sketchengine.eu/bonito/run.cgi'

# %% [markdown]
# Reading based on preloaded British National Corpus (BNC) corpus
# ---
# For association measure see https://www.sketchengine.eu/documentation/statistics-used-in-sketch-engine/ or
# https://www.sketchengine.eu/wp-content/uploads/ske-statistics.pdf

# %% [markdown]
# Parameter |	Type   | Default  | Description
# --------- | ------ | -------- | --------------
# lemma | string | | REQUIRED
# lpos | | |part of speech | in notation ‘-n’, ‘-v’, … but the particular notation depends on a corpus
# maxthesitems | integer | 60 | maximum number of items
# clusteritems | integer (boolean) |	0	| in wsketch is clustercolls: cluster collocations
# minsim | | | minimum similarity between clustered items, relevant only when clustercolls is set to 1

# %%
# thesaurus page access params - similarity and frequency
page = 'thes'  
databnc = {
 'corpname': 'preloaded/bnc2',
 'format': 'json',
 'lemma': 'risk',
 'lpos': '-n',
 'tab': 'basic' 
}
url = base_url + '/%s?corpname=%s' % (page, databnc['corpname'])

#
d = requests.get(url, params=databnc, auth=(USERNAME, API_KEY)).json()
d['Words']
# Out:
# [{'freq': 7440, 'score': 0.3, 'word': 'danger', 'id': 3209},
#  {'freq': 9403, 'score': 0.271, 'word': 'possibility', 'id': 469},
#  {'freq': 12998, 'score': 0.262, 'word': 'difficulty', 'id': 6671},
#  {'freq': 26757, 'score': 0.257, 'word': 'cost', 'id': 4093},
#  {'freq': 7763, 'score': 0.242, 'word': 'consequence', 'id': 3382},
#  {'freq': 15115, 'score': 0.238, 'word': 'benefit', 'id': 8285},
#  {'freq': 24807, 'score': 0.231, 'word': 'value', 'id': 4141},
#  {'freq': 6910, 'score': 0.228, 'word': 'threat', 'id': 7728},
#  {'freq': 7619, 'score': 0.228, 'word': 'impact', 'id': 6192},
#  {'freq': 15289, 'score': 0.223, 'word': 'loss', 'id': 5108},
#  {'freq': 30204, 'score': 0.222, 'word': 'rate', 'id': 3128},
#  {'freq': 55745, 'score': 0.222, 'word': 'problem', 'id': 2482},
#  {'freq': 26921, 'score': 0.218, 'word': 'need', 'id': 2413},
#  {'freq': 33315, 'score': 0.218, 'word': 'effect', 'id': 807},
#  {'freq': 7024, 'score': 0.212, 'word': 'damage', 'id': 7691},
#  {'freq': 16956, 'score': 0.212, 'word': 'amount', 'id': 4208},
#  {'freq': 9753, 'score': 0.211, 'word': 'cause', 'id': 4980},
#  {'freq': 14435, 'score': 0.204, 'word': 'pressure', 'id': 6759},
#  {'freq': 14873, 'score': 0.204, 'word': 'factor', 'id': 341},
#  {'freq': 9579, 'score': 0.203, 'word': 'importance', 'id': 760},
#  {'freq': 1762, 'score': 0.201, 'word': 'incidence', 'id': 1723},
#  {'freq': 5706, 'score': 0.2, 'word': 'expenditure', 'id': 14678},
#  {'freq': 18897, 'score': 0.198, 'word': 'difference', 'id': 72},
#  {'freq': 13760, 'score': 0.197, 'word': 'demand', 'id': 508},
#  {'freq': 35713, 'score': 0.196, 'word': 'level', 'id': 388},
#  {'freq': 9971, 'score': 0.192, 'word': 'extent', 'id': 1666},
#  {'freq': 11979, 'score': 0.191, 'word': 'responsibility', 'id': 5494},
#  {'freq': 33206, 'score': 0.191, 'word': 'result', 'id': 346},
#  {'freq': 13441, 'score': 0.19, 'word': 'income', 'id': 3785},
#  {'freq': 9241, 'score': 0.19, 'word': 'requirement', 'id': 4183},
#  {'freq': 38071, 'score': 0.189, 'word': 'change', 'id': 357},
#  {'freq': 4197, 'score': 0.188, 'word': 'stress', 'id': 5948},
#  {'freq': 4833, 'score': 0.187, 'word': 'liability', 'id': 14093},
#  {'freq': 9006, 'score': 0.187, 'word': 'fear', 'id': 4842},
#  {'freq': 10129, 'score': 0.186, 'word': 'advantage', 'id': 1259},
#  {'freq': 15869, 'score': 0.186, 'word': 'opportunity', 'id': 3212},
#  {'freq': 12879, 'score': 0.185, 'word': 'growth', 'id': 530},
#  {'freq': 18621, 'score': 0.185, 'word': 'quality', 'id': 222},
#  {'freq': 19561, 'score': 0.185, 'word': 'care', 'id': 3206},
#  {'freq': 7769, 'score': 0.184, 'word': 'proportion', 'id': 4199},
#  {'freq': 19569, 'score': 0.184, 'word': 'situation', 'id': 6124},
#  {'freq': 11102, 'score': 0.184, 'word': 'measure', 'id': 3279},
#  {'freq': 12363, 'score': 0.183, 'word': 'investment', 'id': 7782},
#  {'freq': 11491, 'score': 0.183, 'word': 'aspect', 'id': 56},
#  {'freq': 12885, 'score': 0.183, 'word': 'degree', 'id': 111},
#  {'freq': 59926, 'score': 0.183, 'word': 'number', 'id': 246},
#  {'freq': 4633, 'score': 0.183, 'word': 'significance', 'id': 881},
#  {'freq': 23582, 'score': 0.182, 'word': 'condition', 'id': 117},
#  {'freq': 8068, 'score': 0.182, 'word': 'strength', 'id': 2227},
#  {'freq': 21983, 'score': 0.182, 'word': 'experience', 'id': 2350},
#  {'freq': 37191, 'score': 0.181, 'word': 'interest', 'id': 22},
#  {'freq': 22889, 'score': 0.181, 'word': 'activity', 'id': 449},
#  {'freq': 20585, 'score': 0.181, 'word': 'event', 'id': 3688},
#  {'freq': 3677, 'score': 0.178, 'word': 'symptom', 'id': 14503},
#  {'freq': 8129, 'score': 0.178, 'word': 'contribution', 'id': 2466},
#  {'freq': 5913, 'score': 0.177, 'word': 'error', 'id': 724},
#  {'freq': 14764, 'score': 0.176, 'word': 'charge', 'id': 4558},
#  {'freq': 37087, 'score': 0.176, 'word': 'development', 'id': 441},
#  {'freq': 9275, 'score': 0.176, 'word': 'influence', 'id': 2008},
#  {'freq': 25753, 'score': 0.176, 'word': 'type', 'id': 73}]

# %%
# page Wordsketch, collocations and word combinations   same databnc 
page = 'wsketch' 

url = base_url + '/%s?corpname=%s' % (page, databnc['corpname'])

d = requests.get(url, params=databnc, auth=(USERNAME, API_KEY)).json()


print("There are %d grammar relations for %s%s (lemma+PoS) in corpus %s." % (
    len(d['Gramrels']), databnc['lemma'], databnc['lpos'], databnc['corpname']))

for relation in d['Gramrels']:
    print(relation["name"].replace('%w', databnc["lemma"]))
    for word in relation["Words"]:
    
        if("name" in word):
          
            text = word["name"].replace('%w', word["headword"])
        else:
            text = word["cm"]
        print (text, str(word["score"]))
    print("\n")
# Out:
# There are 30 grammar relations for risk (lemma+PoS) in corpus preloaded/bnc2.
# usage patterns
# Sfin 4.43
# VPing 1.36
# poss 1.3
# Swh 0.73
# VPto 0.44
# Sing 0.14
# it+ 0.09
#
#
# modifier
# an increased risk of 9.41
# of subjective risk 9.32
# the relative risk 9.11
# a grave risk that 7.94
# greater risk of 7.81
# potential risks 7.59
# a calculated risk 7.45
# serious risk of 7.31
# high risk of 7.23
# the greatest risk 7.04
# cancer risk 7.0
# a higher risk of 6.95
# measure of objective risk 6.93
# unnecessary risks 6.81
# low risk 6.76
# a real risk of 6.73
# default risk 6.64
# the credit risk 6.6
# of exemplar risk 6.52
# non-market risk 6.52
# systematic risk 6.51
# an unacceptable risk 6.49
# estimated risk 6.44
# health risks 6.42
# excess risk 6.41
#
#
# object_of
# to minimise the risk of 9.17
# reduce the risk of 8.35
#  8.05
# to minimize the risk 8.01
# run the risk of 7.75
# increase the risk of 7.43
# to avoid the risk of 7.27
# eliminate the risk 7.17
# risks associated with 7.06
#  7.04
# insured risks 6.94
# lessen the risk of 6.93
#  6.81
# the risks involved 6.79
#  6.59
#  6.3
#  6.3
#  6.3
#  6.21
#  6.07
#  6.06
#  5.92
# risks attached to 5.92
#  5.78
#  5.67
#
#
# pp_of-p
#  8.65
# the risk of infection 8.24
# risk of harm 7.81
# risk of heart disease 7.46
# risk of damage 7.33
# the risk of contamination 7.32
# the risk of injury 7.25
# risk of suicide 7.2
# risk of transmission 7.15
# increased risk of leukaemia 7.1
# risk of default 7.08
# the risk of depression 6.96
# risk of complications 6.9
# the risk of accidents 6.79
#  6.7
#  6.68
#  6.52
#  6.43
# the risk of litigation 6.43
#  6.43
#  6.4
# risk of prejudice 6.33
#  6.23
# risk of poverty in old age 6.21
#  6.17
#
#
# modifies
# risk ratings 9.36
# the risk premium 9.15
# risk taking 9.0
# risk factors 8.54
# high risk exemplars 8.11
# risk assessment 7.71
# of risk stratification 7.64
# risk aversion 7.56
#  7.05
# low risk junctions 6.92
# risk management 6.28
# risk profile 5.63
#  5.61
#  5.56
#  5.46
# risk reduction 5.08
#  4.96
# of risk issues 4.9
#  4.76
# risk insurance 4.74
#  4.73
# high risk patients 4.69
# risk capital 4.51
#  4.51
#  4.37
#
#
# and/or
#  7.79
# risk and uncertainty 7.12
# the risks and rewards of ownership 7.04
#  6.22
#  6.18
#  5.53
#  5.46
#  4.8
# risks and benefits of 4.77
#  4.71
#  4.63
# between subjective risk and memory 4.41
#  3.39
#  3.07
#  2.99
#  2.86
#  2.77
#  2.74
#  2.56
#  2.5
#  2.25
#  2.09
#  1.69
#  1.53
#  1.4
#
#
# pp_obj_of-p
#  7.67
#  6.93
# aware of the risks 6.88
# the degree of risk 6.39
#  6.19
# perception of risk 6.14
# assessment of risk 6.06
# an element of risk 5.83
#  5.81
#  5.62
#  5.53
#  5.47
#  5.45
#  5.36
#  5.27
# level of risk 5.23
#  5.12
# feelings of risk 4.96
# the extent of the risk 4.87
# reduction of risk 4.82
#  4.17
# types of risk 4.1
#  4.1
#  3.97
#  3.81
#
#
# pp_obj_at-p
# be put at risk 5.01
# patients at risk 4.99
# the population at risk 4.36
#  3.72
# jobs at risk 3.56
# children at risk 3.54
#  3.38
# lives at risk 3.26
#  3.0
#  2.76
#  2.53
# people at risk 2.44
#  2.4
#  2.23
#  1.98
#  1.85
#  1.81
#  1.56
#  1.48
#  0.94
#  0.88
#  0.85
#
#
# subject_of
#  6.18
#  4.82
#  4.68
#  4.67
#  4.6
#  4.33
# risks involved 4.14
# the risk increases 3.51
#  3.35
#  2.92
#  2.92
# risk becomes 2.69
#  2.45
#  2.4
#  1.67
#  1.6
#  0.54
#
#
# pp_to-p
# risks to health 6.22
#  5.25
# risk to the public 4.98
#  4.39
#  4.13
#  3.69
#  3.53
# risk to life 2.91
#  2.86
#  1.78
#  0.03
#
#
# adj_subject_of
# the risks inherent in 8.92
#  8.65
#  7.26
# the risks involved in 5.84
#  4.93
#  4.6
#  4.47
#  4.36
#  3.71
#  3.7
#  3.1
#  3.02
#  2.53
#  2.28
#  2.02
#
#
# pp_from-p
#  7.75
#  4.66
#  3.18
#
#
# pp_in-p
#  2.88
#  1.15
#  0.59
#  0.38
#
#
# pp_obj_to-p
# exposed to the risk of 7.23
#  5.78
#  4.69
#  4.53
#  3.83
#  3.21
#  2.86
#  2.09
#
#
# pp_obj_with-p
#  7.38
#  6.25
#  4.28
#  3.93
#
#
# pp_for-p
#  5.19
#  4.98
#  3.4
#
#
# predicate
#  3.12
#
#
# pp_obj_for-p
#  7.42
#
#
# pp_obj_about-p
#  5.63
#  4.64
#  3.35
#  2.04
#  0.09
#
#
# pp_obj_in-p
# increase in the risk of 5.07
#  5.04
#  2.5
#
#
# pp_obj_against-p
#  8.22
#  6.93
#  4.2
#  3.48
#
#
# predicate_of
#  3.12
#
#
# pp_with-p
#  4.93
#
#
# pp_obj_between-p
# correlation between risk and 7.01
# the relationship between risk and 5.07
#
#
# pp_on-p
#  2.56
#
#
# possessor
#  4.66
#
#
# pp_obj_from-p
#  3.62
#  3.1
#
#
# pp_at-p
#  5.35
#
#
# part_on-a
#  1.23
#
#
# part_down-a
#  3.15
#  1.7

# %%
# Concordances 
page = 'first'
databnc = {
 'corpname': 'preloaded/bnc2',
 'format': 'json',
 'iquery': 'risk',
 'tab': 'basic',    
} 
url = base_url + '/%s?corpname=%s' % (page, databnc['corpname'])

d = requests.get(url, params=databnc, auth=(USERNAME, API_KEY)).json()

for line in d['Lines']:

    left = line["Left"][0]["str"]
    right = line["Right"][0]["str"]
    mid = line["Kwic"][0]["str"]
    
    print(left + " [[" + mid  + " ]] " + right)
# Out:
# Health Officers have said that the [[ risks ]]  to health are" staggering" and have urged a
# 's shell industry puts hawksbill turtle at [[ risk ]] <p>
# floods the reactor core, thereby avoiding the [[ risk ]]  of a partial" meltdown", similar to that which
# children and old people. * Increased cancer [[ risk ]]  from high concentrations of benzene and
# the Gulf as resting places, would shortly be at [[ risk ]]  as they arrived en route from East Africa to
# all suffered from the oil spill, presenting a" [[ risk ]]  that they may not respond to conventional
# Pollution: Water Leningrad's water at [[ risk ]] <p>
# suggested that some unacknowledged health [[ risk ]] , such as an outbreak of the waterborne parasite
# the wealthiest EC countries, Britain as a whole [[ risks ]]  becoming a backward `region' of the Community.
# the changes taking place, without ignoring the [[ risks ]]  involved.
# , accused the government of playing down the [[ risks ]]  so as not to undermine its £4 billion Mersey
# , which make up two thirds of those in the world, [[ risk ]]  becomming underwater deserts.
# to provide sufficient safeguards against the [[ risks ]]  of cross-border pollution and the import of
# water is one of the four greatest environmental [[ risks ]]  facing the population, causing at least 1,000
# 17,000 residents allegedly suffer a cancer [[ risk ]]  several hundred times higher than that which
# that families living in the area were at serious [[ risk ]]  from chemical poisoning. The families were
# or PVC. Undertakers who breach these rules [[ risk ]]  prosecution. The law was introduced after the
# APPROACH TO BUSINESS AND INTELLIGENT [[ RISK ]]  TAKING
# APPROACH TO BUSINESS AND INTELLIGENT [[ RISK ]]  TAKING
# to business. It also means taking intelligent [[ risks ]]  - being prepared to move into uncharted areas,

# %%
# to see the structure of retrived concordances
d['Lines']
# Out:
# [{'Right': [{'class': '',
#     'str': ' to health are" staggering" and have urged a'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risks'}],
#   'Refs': ['Applied science'],
#   'toknum': 73399,
#   'linegroup': '_',
#   'Left': [{'class': '', 'str': 'Health Officers have said that the'}]},
#  {'Right': [{'class': 'strc', 'str': '<p>'},
#    {'class': '', 'str': 'Japan is jeopardising the existence of the'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risk'}],
#   'Refs': ['Applied science'],
#   'toknum': 77562,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': "'s shell industry puts hawksbill turtle at"}]},
#  {'Right': [{'class': '',
#     'str': ' of a partial" meltdown", similar to that which'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risk'}],
#   'Refs': ['Applied science'],
#   'toknum': 82158,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': 'floods the reactor core, thereby avoiding the'}]},
#  {'Right': [{'class': '', 'str': ' from high concentrations of benzene and'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risk'}],
#   'Refs': ['Applied science'],
#   'toknum': 83276,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': 'children and old people. * Increased cancer'}]},
#  {'Right': [{'class': '',
#     'str': ' as they arrived en route from East Africa to'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risk'}],
#   'Refs': ['Applied science'],
#   'toknum': 85485,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': 'the Gulf as resting places, would shortly be at'}]},
#  {'Right': [{'class': '',
#     'str': ' that they may not respond to conventional'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risk'}],
#   'Refs': ['Applied science'],
#   'toknum': 85848,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': 'all suffered from the oil spill, presenting a"'}]},
#  {'Right': [{'class': 'strc', 'str': '<p>'},
#    {'class': '', 'str': 'An abandoned warship is in danger of'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risk'}],
#   'Refs': ['Applied science'],
#   'toknum': 85941,
#   'linegroup': '_',
#   'Left': [{'class': '', 'str': "Pollution: Water Leningrad's water at"}]},
#  {'Right': [{'class': '',
#     'str': ', such as an outbreak of the waterborne parasite'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risk'}],
#   'Refs': ['Applied science'],
#   'toknum': 86140,
#   'linegroup': '_',
#   'Left': [{'class': '', 'str': 'suggested that some unacknowledged health'}]},
#  {'Right': [{'class': '',
#     'str': " becoming a backward `region' of the Community."},
#    {'class': 'strc', 'str': '</p>'}],
#   'hitlen': 1,
#   'Tbl_refs': ['World affairs'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risks'}],
#   'Refs': ['World affairs'],
#   'toknum': 147237,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': 'the wealthiest EC countries, Britain as a whole'}]},
#  {'Right': [{'class': '', 'str': ' involved.'},
#    {'class': 'strc', 'str': '</p><p>'},
#    {'class': '', 'str': 'The European Community was born out'}],
#   'hitlen': 1,
#   'Tbl_refs': ['World affairs'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risks'}],
#   'Refs': ['World affairs'],
#   'toknum': 151469,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': 'the changes taking place, without ignoring the'}]},
#  {'Right': [{'class': '',
#     'str': ' so as not to undermine its £4 billion Mersey'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risks'}],
#   'Refs': ['Applied science'],
#   'toknum': 168205,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': ', accused the government of playing down the'}]},
#  {'Right': [{'class': '', 'str': ' becomming underwater deserts.'},
#    {'class': 'strc', 'str': '</p><p>'},
#    {'class': '', 'str': 'According to'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risk'}],
#   'Refs': ['Applied science'],
#   'toknum': 172714,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': ', which make up two thirds of those in the world,'}]},
#  {'Right': [{'class': '',
#     'str': ' of cross-border pollution and the import of'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risks'}],
#   'Refs': ['Applied science'],
#   'toknum': 174573,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': 'to provide sufficient safeguards against the'}]},
#  {'Right': [{'class': '',
#     'str': ' facing the population, causing at least 1,000'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risks'}],
#   'Refs': ['Applied science'],
#   'toknum': 180406,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': 'water is one of the four greatest environmental'}]},
#  {'Right': [{'class': '',
#     'str': ' several hundred times higher than that which'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risk'}],
#   'Refs': ['Applied science'],
#   'toknum': 180514,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': '17,000 residents allegedly suffer a cancer'}]},
#  {'Right': [{'class': '',
#     'str': ' from chemical poisoning. The families were'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risk'}],
#   'Refs': ['Applied science'],
#   'toknum': 180894,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': 'that families living in the area were at serious'}]},
#  {'Right': [{'class': '',
#     'str': ' prosecution. The law was introduced after the'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risk'}],
#   'Refs': ['Applied science'],
#   'toknum': 183544,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': 'or PVC. Undertakers who breach these rules'}]},
#  {'Right': [{'class': '', 'str': ' TAKING'},
#    {'class': 'strc', 'str': '</p><p>'},
#    {'class': '', 'str': 'A DISTINCTIVE COMPETITIVE EDGE ON'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' RISK'}],
#   'Refs': ['Applied science'],
#   'toknum': 183895,
#   'linegroup': '_',
#   'Left': [{'class': '', 'str': 'APPROACH TO BUSINESS AND INTELLIGENT'}]},
#  {'Right': [{'class': '', 'str': ' TAKING'},
#    {'class': 'strc', 'str': '<p>'},
#    {'class': '', 'str': "Becoming the world's foremost brewer"}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' RISK'}],
#   'Refs': ['Applied science'],
#   'toknum': 184602,
#   'linegroup': '_',
#   'Left': [{'class': '', 'str': 'APPROACH TO BUSINESS AND INTELLIGENT'}]},
#  {'Right': [{'class': '',
#     'str': ' - being prepared to move into uncharted areas,'}],
#   'hitlen': 1,
#   'Tbl_refs': ['Applied science'],
#   'linegroup_id': 0,
#   'Links': [],
#   'Kwic': [{'class': 'col0 coll', 'str': ' risks'}],
#   'Refs': ['Applied science'],
#   'toknum': 184632,
#   'linegroup': '_',
#   'Left': [{'class': '',
#     'str': 'to business. It also means taking intelligent'}]}]

# %% [markdown]
# Reading based on corpus  created by user
# ---

# %%
# thesaurus page user corpus
page = 'thes'  
datauser = {
 'corpname': 'user%2FAleksandraTomasevic%2Frudkor',
 'format': 'json',
 'lemma': 'rizik',
 'tab': 'basic',    
 'showScores' :'1',
 'showresults':'1',
}
url = base_url + '/%s?corpname=%s' % (page, datauser['corpname'])

d = requests.get(url, params=datauser, auth=(USERNAME, API_KEY)).json()
d['Words']
# Out:
# [{'freq': 1177, 'score': 0.312, 'word': 'opasnost', 'id': 3647},
#  {'freq': 2512, 'score': 0.307, 'word': 'riziko', 'id': 107},
#  {'freq': 1173, 'score': 0.171, 'word': 'posledica', 'id': 1237},
#  {'freq': 2387, 'score': 0.166, 'word': 'problem', 'id': 1574},
#  {'freq': 2222, 'score': 0.166, 'word': 'trošak', 'id': 465},
#  {'freq': 1972, 'score': 0.154, 'word': 'faktor', 'id': 1385},
#  {'freq': 1976, 'score': 0.148, 'word': 'aktivnost', 'id': 51},
#  {'freq': 1177, 'score': 0.135, 'word': 'resurs', 'id': 6448},
#  {'freq': 1486, 'score': 0.135, 'word': 'mogućnost', 'id': 1399},
#  {'freq': 664, 'score': 0.133, 'word': 'ograničenje', 'id': 1102},
#  {'freq': 3046, 'score': 0.132, 'word': 'cilj', 'id': 48},
#  {'freq': 1299, 'score': 0.129, 'word': 'odluka', 'id': 570},
#  {'freq': 672, 'score': 0.128, 'word': 'situacija', 'id': 747},
#  {'freq': 293, 'score': 0.123, 'word': 'neizvesnost', 'id': 6709},
#  {'freq': 1285, 'score': 0.122, 'word': 'kvalitet', 'id': 2878},
#  {'freq': 3741, 'score': 0.122, 'word': 'broj', 'id': 25},
#  {'freq': 2582, 'score': 0.121, 'word': 'uticaj', 'id': 735},
#  {'freq': 2913, 'score': 0.121, 'word': 'bezbednost', 'id': 5},
#  {'freq': 2051, 'score': 0.12, 'word': 'količina', 'id': 765},
#  {'freq': 4739, 'score': 0.119, 'word': 'zaštita', 'id': 171},
#  {'freq': 2391, 'score': 0.119, 'word': 'zahtev', 'id': 1037},
#  {'freq': 2792, 'score': 0.117, 'word': 'sadržaj', 'id': 730},
#  {'freq': 3676, 'score': 0.116, 'word': 'mera', 'id': 50},
#  {'freq': 913, 'score': 0.115, 'word': 'aspekt', 'id': 2269},
#  {'freq': 3502, 'score': 0.112, 'word': 'rezultat', 'id': 237},
#  {'freq': 1382, 'score': 0.112, 'word': 'izvor', 'id': 4530},
#  {'freq': 2141, 'score': 0.112, 'word': 'karakteristika', 'id': 663},
#  {'freq': 3037, 'score': 0.111, 'word': 'nivo', 'id': 280},
#  {'freq': 450, 'score': 0.111, 'word': 'odgovornost', 'id': 11134},
#  {'freq': 2800, 'score': 0.108, 'word': 'brzina', 'id': 772},
#  {'freq': 1705, 'score': 0.108, 'word': 'posao', 'id': 5554},
#  {'freq': 721, 'score': 0.108, 'word': 'osobina', 'id': 673},
#  {'freq': 2179, 'score': 0.108, 'word': 'promena', 'id': 1768},
#  {'freq': 1848, 'score': 0.107, 'word': 'kapacitet', 'id': 805},
#  {'freq': 3640, 'score': 0.106, 'word': 'deo', 'id': 812},
#  {'freq': 829, 'score': 0.106, 'word': 'dimenzija', 'id': 2368},
#  {'freq': 1557, 'score': 0.106, 'word': 'stepen', 'id': 1118},
#  {'freq': 781, 'score': 0.105, 'word': 'projekat', 'id': 8483},
#  {'freq': 1193, 'score': 0.105, 'word': 'pojava', 'id': 1406},
#  {'freq': 7175, 'score': 0.105, 'word': 'proces', 'id': 733},
#  {'freq': 2790, 'score': 0.104, 'word': 'stanje', 'id': 461},
#  {'freq': 564, 'score': 0.104, 'word': 'greška', 'id': 6734},
#  {'freq': 1014, 'score': 0.104, 'word': 'propis', 'id': 120},
#  {'freq': 1250, 'score': 0.103, 'word': 'proizvod', 'id': 744},
#  {'freq': 993, 'score': 0.103, 'word': 'tehnologija', 'id': 308},
#  {'freq': 4256, 'score': 0.103, 'word': 'upravljanje', 'id': 2750},
#  {'freq': 819, 'score': 0.103, 'word': 'pitanje', 'id': 38},
#  {'freq': 521, 'score': 0.103, 'word': 'politika', 'id': 11200},
#  {'freq': 913, 'score': 0.102, 'word': 'lokacija', 'id': 989},
#  {'freq': 2833, 'score': 0.102, 'word': 'vreme', 'id': 724},
#  {'freq': 2211, 'score': 0.102, 'word': 'organizacija', 'id': 193},
#  {'freq': 2597, 'score': 0.101, 'word': 'oprema', 'id': 966},
#  {'freq': 1731, 'score': 0.101, 'word': 'standard', 'id': 3224},
#  {'freq': 3046, 'score': 0.101, 'word': 'parametar', 'id': 764},
#  {'freq': 1624, 'score': 0.101, 'word': 'kriterijum', 'id': 2139},
#  {'freq': 639, 'score': 0.099, 'word': 'pokazatelj', 'id': 1947},
#  {'freq': 406, 'score': 0.099, 'word': 'gubitak', 'id': 957},
#  {'freq': 5001, 'score': 0.099, 'word': 'uslov', 'id': 95},
#  {'freq': 1652, 'score': 0.099, 'word': 'sila', 'id': 1795},
#  {'freq': 1272, 'score': 0.098, 'word': 'struktura', 'id': 3394}]

# %%
# Wordsketch page access
page = 'wsketch'
datauser = {
 'corpname': 'user%2FAleksandraTomasevic%2Frudkor',
 'format': 'json',
 'lemma': 'rizik',
 'lpos': '',
 'tab': 'basic',    
}

url = base_url + '/%s?corpname=%s' % (page, datauser['corpname'])

d = requests.get(url, params=datauser, auth=(USERNAME, API_KEY)).json()


print("There are %d grammar relations for %s%s (lemma+PoS) in corpus %s." % (
    len(d['Gramrels']), datauser['lemma'], datauser['lpos'], datauser['corpname']))

for relation in d['Gramrels']:
    print(relation["name"].replace('%w', datauser["lemma"]))
    for word in relation["Words"]:
    
        if("name" in word):
          
            text = word["name"].replace('%w', word["headword"])
        else:
            text = word["cm"]
        print (text, str(word["score"]))
    print("\n")
# Out:
# There are 12 grammar relations for rizik (lemma+PoS) in corpus user%2FAleksandraTomasevic%2Frudkor.
# verb prepositional phrases
# "rizik" od ... 14.65
# ... od "rizik" 14.65
# "rizik" sa ... 11.62
# ... sa "rizik" 11.62
# "rizik" u ... 4.97
# ... u "rizik" 4.97
# "rizik" po ... 4.55
# ... po "rizik" 4.55
# "rizik" na ... 3.87
# ... na "rizik" 3.87
# "rizik" za ... 2.1
# ... za "rizik" 2.1
# "rizik" prema ... 0.76
# ... prema "rizik" 0.76
# "rizik" o ... 0.67
# ... o "rizik" 0.67
# "rizik" kroz ... 0.51
# ... kroz "rizik" 0.51
# "rizik" tokom ... 0.25
# ... tokom "rizik" 0.25
# "rizik" nad ... 0.25
# ... nad "rizik" 0.25
#
#
# modifiers of "rizik"
# radnom mestu sa povećanim rizikom 12.49
# potencijalni rizik 9.68
# politički rizik 9.06
# identifikovani i rangirani rizici 8.19
# procenjeni rizici 8.01
# neprihvatljiv Uopšteno • visoki rizik 7.97
# su zaposleni posebno izloženi rizicima u slučaju nestanka 7.92
# neophodna zbog upravljanja OHS rizicima . To uključuje 7.86
# kojima se pojavljuje specifičan rizik od nastanka povreda 7.8
# zaposlenih rizicima 7.66
# Inženjerski rizici 7.52
# Rizici 7.44
# sa izvesnim rizikom od izbijanja požara 7.4
# visok rizik 7.34
# mogući rizici 7.13
# kritičnim rizicima 7.03
# ekonomski ili politički rizici 6.93
# to da li postojeći rizici mogu da se 6.93
# mesta gde su zaposleni posebno izloženi rizicima u slučaju nestanka 6.92
# Toksičnost i potencijalni ekološki rizici 6.8
# mali rizik 6.74
# Glavni rizici u rudarstvu Glavni 6.66
# značajan rizik 6.56
# Realni rizik 6.56
# veći rizik 6.22
#
#
# verbs with "rizik" as subject
# bi se smanjio rizik 8.98
# preventivnih mera , rizik koji nastaje usled izloženosti zaposlenih 8.9
# rizik ukoliko postoji 8.52
# identifikuju opasnosti i rizici , te se definišu potrebne kontrole vezeno 8.18
# rizik može 7.71
# rizik treba 6.2
# identifikuju opasnosti i rizici vezane uz promene , organizacija mora osigurati da se 6.11
# Rizik predstavlja 6.07
# rizik vezan za profitabilnost ima 5.62
#
#
# verbs with "rizik" as accusative object
# postoji rizik od 10.82
# smanji rizik od 10.57
# da proceni rizik 10.42
# u značajnoj meri smanjuje rizik i olakšava proces 9.31
# način koji bi eliminisao rizik ? Korak 8.94
# nose dosta veliki rizik 8.56
# povećava rizik 8.24
# predstavlja rizik 8.22
# utvrditi i mogući rizik 7.77
# sadrži minimalni rizik 6.52
#
#
# conjunctions after "rizik"
# sa visokim rizikom od izbijanja požara 9.69
# rizik kako 6.76
# mestu sa povećanim rizikom kao i pre premeštaja 5.66
# sa povećanim rizikom i 4.91
# mestu sa povećanim rizikom ili za upotrebu 4.69
# postoji rizik da 3.78
#
#
# "rizik" and/or ...
# mesta sa povećanim rizikom i lekarskim pregledima zaposlenih raspoređenih 11.53
# identifikuju opasnosti i rizici 10.14
# aktivnosti , te rizici i složenost njenih radnih operacija 10.03
# mestima sa povećanim rizikom i ciljane lekarske preglede 10.02
#
#
# "rizik" as ...
# procenjeni rizici 10.08
# identifikovani i rangirani rizici 8.84
# rizik povezan sa 8.79
# preventivnih mera , rizik koji nastaje usled izloženosti zaposlenih 8.58
# smanjen politički rizik 8.49
# rizik vezan za 7.83
# dobijeno je da rizik od 6.36
#
#
# pronouns after "rizik"
# rizik nekog 6.23
# rizik koji 6.22
#
#
# prepositions before "rizik"
# najpre obezbediti kontrolu nad rizicima po zdravlje i 8.08
# o rizicima 5.78
# njihovim vrednostima , prema rizicima i sl. 5.49
# sa rizicima 4.99
# odgovora na rizik 3.22
# i najverojatnije zainteresovana za rizik , pa samim 2.62
#
#
# noun objects of "rizik" as infinitive
# može se pravilno upravljati rizicima poslovanja 11.54
# Kako se može proceniti rizik koji proizilazi iz 11.16
# i smanjiti rizik 10.22
# predstavljati rizik 10.1
# biti izloženi rizicima 6.55
#
#
# nouns of genitive "rizik"
# Dozvoljeni rizici zarušavanja 10.22
# se pravilno upravljati rizicima poslovanja 9.61
# rizicima organizacije . Merenje 7.98
#
#
# "rizik% before reflexive verb
# da se smanje rizici 11.15
# bave rizikom 9.39
# kako bi se rizik od infekcije smanjio 8.22
